# %%
import pandas as pd

# %%
df = pd.read_csv('month-overview.csv')
df.head()
# Out:
#           timestamp          host                      item  \
# 0  2026-07-02 20:00  HMI-GRS-WW01      CPU Core Temperature
# 1  2026-07-02 20:00  HMI-GRS-WW01           CPU Utilization
# 2  2026-07-02 20:00  HMI-GRS-WW01  System/Chassis Fan Speed
# 3  2026-07-02 20:00  HMI-GRS-WW01          Memory Available
# 4  2026-07-02 20:00  HMI-TBB-WW01      CPU Core Temperature
#
#                  key        value units
# 0       hmi.cpu.temp    70.657425    °C
# 1       hmi.cpu.util    28.362392     %
# 2        hmi.fan.rpm  2026.904375   rpm
# 3  hmi.mem.available    49.499292     %
# 4       hmi.cpu.temp    68.919558    °C
