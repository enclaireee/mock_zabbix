# %%
import pandas as pd

df = pd.read_csv('laporan_6bulan.csv')

row_count = df.shape[0]
col_count = df.shape[1]
column_names = df.columns.tolist()

print(f"rowcount = {row_count:,} rows")
print(f"collumn count = {col_count} column")
print(f"column names ={column_names}")
# Out:
# /var/folders/73/nlbhy2cj0js4krbnh0_z8jf00000gn/T/ipykernel_32683/1946843119.py:3: DtypeWarning: Columns (0: value, 1: units) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('laporan_6bulan.csv')
# rowcount = 9,218,499 rows
# collumn count = 6 column
# column names =['timestamp', 'host', 'item', 'key', 'value', 'units']
